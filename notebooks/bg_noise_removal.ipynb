# %% [markdown]
# ### The noise reduce library is written by [Tim Sainburg](https://timsainburg.com/noise-reduction-python.html)
# Install instructions
#
# !pip install noisereduce

# %%
import os
import csv
import librosa
import librosa.display
import torch
import numpy as np
import matplotlib.pyplot as plt
import IPython.display as ipd
import cv2
import scipy
from skimage.restoration import (denoise_wavelet, estimate_sigma)
import noisereduce as nr

# %%
fname   =  '/data/durgesh/orca206/orca_al/data_source/podcastR2_mini/1562340736_0006_0017.wav'
fs     = librosa.get_samplerate(fname)
y, fs = librosa.load(fname,fs)
x     = np.arange(0,len(y))/fs

print('Audio duration ={} seconds,Sampling rate={},n_samples={}'.format(len(y)/fs,fs,len(y)))
ipd.Audio(y,rate=fs)
# Out:
# Audio duration =2.45 seconds,Sampling rate=44100,n_samples=108045
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
reduced_noise = nr.reduce_noise(audio_clip=y, noise_clip=y, verbose=True)
ipd.Audio(reduced_noise,rate=fs)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=7.0), HTML(value='')))
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
